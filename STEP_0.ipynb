# %%
import random
import pandas as pd

# %%
df=pd.read_csv('cab_rides.csv')

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %%
df.isna().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
print(df['destination'].unique())
# Out:
# ['North Station' 'Northeastern University' 'West End' 'Haymarket Square'
#  'South Station' 'Fenway' 'Theatre District' 'Beacon Hill' 'Back Bay'
#  'North End' 'Financial District' 'Boston University']

# %%
for index, row in df.iterrows():
    if row['destination'] == 'North Station':
        df.at[index, 'destination'] = 'North+Station,+Boston,+MA,+USA'
    if row['destination'] == 'Northeastern University':
        df.at[index,'destination'] = 'Northeastern+University,+Boston,+MA,+USA'
    if row['destination'] == 'West End': 
        df.at[index,'destination'] = 'West+End,+Boston,+MA,+USA'
    if row['destination'] == 'Haymarket Square': 
        df.at[index,'destination'] = 'Haymarket+Square,+Boston,+MA,+USA'
    if row['destination'] == 'South Station': 
        df.at[index,'destination'] = 'South+Station,+Boston,+MA,+USA'
    if row['destination'] == 'Fenway': 
        df.at[index,'destination'] = 'Fenway,+Boston,+MA,+USA'
    if row['destination'] == 'Theatre District': 
        df.at[index,'destination'] = 'Theatre+District,+Boston,+MA,+USA'
    if row['destination'] == 'Beacon Hill': 
        df.at[index,'destination'] = 'Beacon+Hill,+Boston,+MA,+USA'
    if row['destination'] == 'Back Bay': 
        df.at[index,'destination'] = 'Back+Bay,+Boston,+MA,+USA' 
    if row['destination'] == 'North End': 
        df.at[index,'destination'] = 'North+End,+Boston,+MA,+USA' 
    if row['destination'] == 'Boston University': 
        df.at[index,'destination'] = 'Boston+University,+Boston,+MA,+USA'     
    if row['destination'] == 'Financial District': 
        df.at[index,'destination'] = 'Financial+District,+Boston,+MA,+USA'

# %%
df.head(10)
# Out:
#    distance cab_type     time_stamp                               destination  \
# 0      0.44     Lyft  1544952607890            North+Station,+Boston,+MA,+USA
# 1      0.44     Lyft  1543284023677            North+Station,+Boston,+MA,+USA
# 2      0.44     Lyft  1543366822198            North+Station,+Boston,+MA,+USA
# 3      0.44     Lyft  1543553582749            North+Station,+Boston,+MA,+USA
# 4      0.44     Lyft  1543463360223            North+Station,+Boston,+MA,+USA
# 5      0.44     Lyft  1545071112138            North+Station,+Boston,+MA,+USA
# 6      1.08     Lyft  1543208580200  Northeastern+University,+Boston,+MA,+USA
# 7      1.08     Lyft  1543780384677  Northeastern+University,+Boston,+MA,+USA
# 8      1.08     Lyft  1543818482645  Northeastern+University,+Boston,+MA,+USA
# 9      1.08     Lyft  1543315522249  Northeastern+University,+Boston,+MA,+USA
#
#              source  price  surge_multiplier  \
# 0  Haymarket Square    5.0               1.0
# ...

# %%
for index, row in df.iterrows():
    if row['source'] == 'North Station':
        df.at[index, 'source'] = 'North+Station,+Boston,+MA,+USA'
    if row['source'] == 'Northeastern University':
        df.at[index,'source'] = 'Northeastern+University,+Boston,+MA,+USA'
    if row['source'] == 'West End': 
        df.at[index,'source'] = 'West+End,+Boston,+MA,+USA'
    if row['source'] == 'Haymarket Square': 
        df.at[index,'source'] = 'Haymarket+Square,+Boston,+MA,+USA'
    if row['source'] == 'South Station': 
        df.at[index,'source'] = 'South+Station,+Boston,+MA,+USA'
    if row['source'] == 'Fenway': 
        df.at[index,'source'] = 'Fenway,+Boston,+MA,+USA'
    if row['source'] == 'Theatre District': 
        df.at[index,'source'] = 'Theatre+District,+Boston,+MA,+USA'
    if row['source'] == 'Beacon Hill': 
        df.at[index,'source'] = 'Beacon+Hill,+Boston,+MA,+USA'
    if row['source'] == 'Back Bay': 
        df.at[index,'source'] = 'Back+Bay,+Boston,+MA,+USA' 
    if row['source'] == 'North End': 
        df.at[index,'source'] = 'North+End,+Boston,+MA,+USA' 
    if row['source'] == 'Boston University': 
        df.at[index,'source'] = 'Boston+University,+Boston,+MA,+USA'     
    if row['source'] == 'Financial District': 
        df.at[index,'source'] = 'Financial+District,+Boston,+MA,+USA'

# %%
df['class_hour']=None

# %%
df.shape
# Out:
# (693071, 11)

# %%
import datetime
#convert 13digit time stamp to datetime format
df['date_time']= pd.to_datetime(df['time_stamp']/1000, unit='s')
df['date']= df['date_time'].dt.date
df['day'] = df.date_time.dt.dayofweek
df['hour'] = df.date_time.dt.hour

# %%
df.head()
# Out:
#    distance cab_type     time_stamp                     destination  \
# 0      0.44     Lyft  1544952607890  North+Station,+Boston,+MA,+USA
# 1      0.44     Lyft  1543284023677  North+Station,+Boston,+MA,+USA
# 2      0.44     Lyft  1543366822198  North+Station,+Boston,+MA,+USA
# 3      0.44     Lyft  1543553582749  North+Station,+Boston,+MA,+USA
# 4      0.44     Lyft  1543463360223  North+Station,+Boston,+MA,+USA
#
#                               source  price  surge_multiplier  \
# 0  Haymarket+Square,+Boston,+MA,+USA    5.0               1.0
# 1  Haymarket+Square,+Boston,+MA,+USA   11.0               1.0
# 2  Haymarket+Square,+Boston,+MA,+USA    7.0               1.0
# 3  Haymarket+Square,+Boston,+MA,+USA   26.0               1.0
# 4  Haymarket+Square,+Boston,+MA,+USA    9.0               1.0
#
#                                      id    product_id          name  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line        Shared
# ...

# %%
for i in range(0,637976):
    if df['hour'][i]>=0 and df['hour'][i]<=3:
        df['class_hour'][i]=0
    if df['hour'][i]>=4 and df['hour'][i]<=6:
        df['class_hour'][i]=1
    if df['hour'][i]>=7 and df['hour'][i]<=9:
        df['class_hour'][i]=2   
    if df['hour'][i]>=10 and df['hour'][i]<=12:
        df['class_hour'][i]=3       
    if df['hour'][i]>=13 and df['hour'][i]<=15:
        df['class_hour'][i]=4    
    if df['hour'][i]>=16 and df['hour'][i]<=18:
        df['class_hour'][i]=5     
    if df['hour'][i]>=19 and df['hour'][i]<=21:
        df['class_hour'][i]=6    
    if df['hour'][i]>=22 and df['hour'][i]<=24:
        df['class_hour'][i]=7
# Out:
# C:\Users\Yash Mahajan\AppData\Local\Temp\ipykernel_7112\129741610.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class_hour'][i]=2
# C:\Users\Yash Mahajan\AppData\Local\Temp\ipykernel_7112\129741610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class_hour'][i]=0
# C:\Users\Yash Mahajan\AppData\Local\Temp\ipykernel_7112\129741610.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head(20)

# %%
df.isna().sum()

# %%
df.head(40)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()

# %%
df.to_csv('cab_rides_project1.csv')
